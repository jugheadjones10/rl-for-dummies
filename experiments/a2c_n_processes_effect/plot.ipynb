# %%
# Import plot functions from utils/plot.py

import sys

sys.path.append("/Users/kimyoungjin/Projects/monkey/rl-for-dummies/experiments/utils")

from plot import plot_average, plot_multiple_averages

# %%
plot_average("vanilla_8_process", "8 Processes")

# %%
plot_average("vanilla_16_processes", "16 Processes")

# %%
plot_average("vanilla_32_processes", "32 Processes")

# %%
plot_average("vanilla_64_processes", "64 Processes")

# %%
plot_multiple_averages(
    [
        "vanilla_8_process",
        "vanilla_16_processes",
        "vanilla_32_processes",
        "vanilla_64_processes",
    ],
    "Vanilla 1 and 16 and 32 and 64 Processes",
)
